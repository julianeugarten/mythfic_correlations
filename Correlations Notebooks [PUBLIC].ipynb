# %% [markdown]
# # Code for calculating correlations between fanfiction-features from MythFic Metadata
# Associated with the paper *Rewriting the Mythological Canon: Dynamics of Popularity and Correlation in Fanfiction about Greek Myth* for the *When Readers Become Writers* conference,

# %% [markdown]
# ## Import some requirements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
import IPython.display as display
import openpyxl

# %% [markdown]
# ## Open the csv of data from Github

# %%
df = pd.read_csv('popularity+binary_characters_genres_categories_ratings.csv')

# %% [markdown]
# ## Little bit of pre-processing

# %%
# take out the chapters column because it is formatted differently from the others
# doing something with number of chapters may be nice for future work
df = df.drop(columns = ["chapters"])

# %% [markdown]
# ## Calculate Spearman's Rho
#
# Also calculate p-values and set a significance threshold of <0.05
# Then add the heatmap layout and print the results
#
# NB: Chat-GPT assisted me in creating this code.

# %%
# Fill NaN values with 0 (if any)
df = df.fillna(0)

# Function to compute Spearman correlation matrix and p-value matrix
def spearman_correlation_with_pvalues(df):
    # Select only numeric columns to avoid non-numeric data
    df_numeric = df.select_dtypes(include=[np.number])
    
    # Initialize empty matrices
    corr = df_numeric.corr(method='spearman')  # Spearman correlation matrix
    pvals = pd.DataFrame(np.ones_like(corr, dtype=float), columns=corr.columns, index=corr.index)  # p-value matrix
    
    # Compute Spearman's rank correlation and p-values using scipy.stats.spearmanr
    for i in range(len(df_numeric.columns)):
        for j in range(i + 1, len(df_numeric.columns)):
            corr_val, p_val = spearmanr(df_numeric.iloc[:, i], df_numeric.iloc[:, j])
            pvals.iloc[i, j] = p_val
            pvals.iloc[j, i] = p_val  # Symmetric matrix
    
    return corr, pvals

# Compute the Spearman correlation matrix and p-value matrix
corr_matrix, pval_matrix = spearman_correlation_with_pvalues(df)

# Set a significance threshold (e.g., p-value < 0.05)
threshold = 0.05

# Mask non-significant correlations (p-value > threshold)
significant_corr_matrix = corr_matrix.copy()
significant_corr_matrix[pval_matrix > threshold] = np.nan  # Set non-significant correlations to NaN

# Display the correlation matrix with color-coding
styled_matrix = significant_corr_matrix.style.background_gradient(cmap="coolwarm", axis=None).format(
    "{:.2f}"
)

# Display the styled matrix
display.display(styled_matrix)
# Out:
# /var/folders/0p/y13f3r_n4rvfvg1hjr765xnw0000gp/T/ipykernel_28194/1093453615.py:16: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr_val, p_val = spearmanr(df_numeric.iloc[:, i], df_numeric.iloc[:, j])
# <style type="text/css">
# #T_347fc_row0_col0, #T_347fc_row0_col6, #T_347fc_row0_col8, #T_347fc_row0_col9, #T_347fc_row0_col20, #T_347fc_row0_col31, #T_347fc_row0_col32, #T_347fc_row1_col1, #T_347fc_row1_col5, #T_347fc_row1_col10, #T_347fc_row1_col11, #T_347fc_row1_col12, #T_347fc_row1_col14, #T_347fc_row1_col15, #T_347fc_row1_col16, #T_347fc_row1_col28, #T_347fc_row1_col30, #T_347fc_row1_col31, #T_347fc_row2_col2, #T_347fc_row2_col16, #T_347fc_row2_col28, #T_347fc_row2_col30, #T_347fc_row2_col31, #T_347fc_row3_col3, #T_347fc_row3_col15, #T_347fc_row3_col16, #T_347fc_row3_col28, #T_347fc_row3_col30, #T_347fc_row3_col31, #T_347fc_row4_col4, #T_347fc_row4_col21, #T_347fc_row4_col28, #T_347fc_row4_col31, #T_347fc_row5_col1, #T_347fc_row5_col5, #T_347fc_row5_col7, #T_347fc_row5_col18, #T_347fc_row5_col20, #T_347fc_row5_col21, #T_347fc_row5_col22, #T_347fc_row5_col23, #T_347fc_row5_col24, #T_347fc_row5_col29, #T_347fc_row5_col30, #T_347fc_row5_col31, #T_347fc_row5_col32, #T_347fc_row6_col0, #T_347fc_row6_col6, #T_347fc_row6_col12, #T_347fc_row6_col15, #T_347fc_row6_col16, #T_347fc_row6_col17, #T_347fc_row6_col18, #T_347fc_row6_col20, #T_347fc_row6_col21, #T_347fc_row6_col22, #T_347fc_row6_col23, #T_347fc_row6_col24, #T_347fc_row6_col25, #T_347fc_row6_col28, #T_347fc_row6_col30, #T_347fc_row6_col31, #T_347fc_row6_col32, #T_347fc_row7_col5, #T_347fc_row7_col7, #T_347fc_row7_col16, #T_347fc_row7_col17, #T_347fc_row7_col20, #T_347fc_row7_col21, #T_347fc_row7_col22, #T_347fc_row7_col23, #T_347fc_row7_col24, #T_347fc_row7_col25, #T_347fc_row7_col30, #T_347fc_row7_col31, #T_347fc_row7_col32, #T_347fc_row8_col0, #T_347fc_row8_col8, #T_347fc_row8_col21, #T_347fc_row8_col23, #T_347fc_row8_col24, #T_347fc_row8_col25, #T_347fc_row8_col30, #T_347fc_row8_col31, #T_347fc_row9_col0, #T_347fc_row9_col9, #T_347fc_row9_col21, #T_347fc_row9_col23, #T_347fc_row9_col24, #T_347fc_row9_col25, #T_347fc_row9_col30, #T_347fc_row9_col31, #T_347fc_row10_col1, #T_347fc_row10_col10, #T_347fc_row10_col17, #T_347fc_row10_col18, #T_347fc_row10_col20, #T_347fc_row10_col21, #T_347fc_row10_col23, #T_347fc_row10_col24, #T_347fc_row10_col25, #T_347fc_row10_col28, #T_347fc_row10_col29, #T_347fc_row10_col31, #T_347fc_row11_col1, #T_347fc_row11_col11, #T_347fc_row11_col17, #T_347fc_row11_col18, #T_347fc_row11_col19, #T_347fc_row11_col20, #T_347fc_row11_col21, #T_347fc_row11_col23, #T_347fc_row11_col24, #T_347fc_row11_col25, #T_347fc_row11_col28, #T_347fc_row11_col29, #T_347fc_row11_col31, #T_347fc_row11_col32, #T_347fc_row12_col1, #T_347fc_row12_col6, #T_347fc_row12_col12, #T_347fc_row12_col17, #T_347fc_row12_col18, #T_347fc_row12_col19, #T_347fc_row12_col20, #T_347fc_row12_col21, #T_347fc_row12_col23, #T_347fc_row12_col25, #T_347fc_row12_col27, #T_347fc_row12_col29, #T_347fc_row12_col31, #T_347fc_row12_col32, #T_347fc_row13_col13, #T_347fc_row13_col17, #T_347fc_row13_col18, #T_347fc_row13_col19, #T_347fc_row13_col21, #T_347fc_row13_col22, #T_347fc_row13_col23, #T_347fc_row13_col25, #T_347fc_row13_col29, #T_347fc_row13_col30, #T_347fc_row13_col31, #T_347fc_row13_col32, #T_347fc_row14_col1, #T_347fc_row14_col14, #T_347fc_row14_col17, #T_347fc_row14_col18, #T_347fc_row14_col20, #T_347fc_row14_col21, #T_347fc_row14_col25, #T_347fc_row14_col31, #T_347fc_row15_col1, #T_347fc_row15_col3, #T_347fc_row15_col6, #T_347fc_row15_col15, #T_347fc_row15_col17, #T_347fc_row15_col18, #T_347fc_row15_col19, #T_347fc_row15_col21, #T_347fc_row15_col22, #T_347fc_row15_col23, #T_347fc_row15_col24, #T_347fc_row15_col25, #T_347fc_row15_col26, #T_347fc_row15_col27, #T_347fc_row15_col29, #T_347fc_row15_col31, #T_347fc_row15_col32, #T_347fc_row16_col1, #T_347fc_row16_col2, #T_347fc_row16_col3, #T_347fc_row16_col6, #T_347fc_row16_col7, #T_347fc_row16_col16, #T_347fc_row16_col17, #T_347fc_row16_col19, #T_347fc_row16_col20, #T_347fc_row16_col21, #T_347fc_row16_col22, #T_347fc_row16_col23, #T_347fc_row16_col24, #T_347fc_row16_col25, #T_347fc_row16_col26, #T_347fc_row16_col31, #T_347fc_row17_col6, #T_347fc_row17_col7, #T_347fc_row1 ...

# %% [markdown]
# # Export output to Excel if desired

# %%
styled_matrix.to_excel('styled.xlsx', engine='openpyxl')
